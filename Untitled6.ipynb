# %%
from dateutil.parser import parse 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

# %%
df = pd.read_csv('BDM\India_02_v2.csv', parse_dates=['Date_reported'])
df.head()
# Out:
#               Date_reported  Cumulative_cases
# 0 2020-01-30 00:00:00+00:00                 1
# 1 2020-01-31 00:00:00+00:00                 1
# 2 2020-02-01 00:00:00+00:00                 1
# 3 2020-02-02 00:00:00+00:00                 2
# 4 2020-02-03 00:00:00+00:00                 3

# %%
sns.set(rc={'figure.figsize':(11, 4)})

# %%
df['Cumulative_cases'].plot(linewidth=0.5);

# %%
df.dtypes
# Out:
# Date_reported       datetime64[ns, UTC]
# Cumulative_cases                  int64
# dtype: object

# %%
df = df.set_index('Date_reported')

# %%
df['Cumulative_cases'].plot(linewidth=0.5);

# %%
from pandas.plotting import autocorrelation_plot
from matplotlib import pyplot

autocorrelation_plot(df)
pyplot.show()
